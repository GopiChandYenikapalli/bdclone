# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo
import credentials
connection_string = 'mongodb+srv://ism6562:8155000769Gc@cluster0.mx8tc2l.mongodb.net/'
#connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.d130e9a.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(connection_string)
db = client['cardio'] # this is a 'database'
collection = db['patients'] # this is a 'collection'

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [5], 'patient_info': {'fname': 'Tom', 'lname': 'Granger', 'mname': 'Jane'}, 'patient_numbers': ['069-023-3236', '608-843-1903', '823-191-2834'], 'weights': [245, 161, 393, 353, 276], 'height': 116, 'bp_readings': [{'Systolic': 137, 'Diastolic': 93, 'Rate': 85}, {'Systolic': 147, 'Diastolic': 76, 'Rate': 92}, {'Systolic': 137, 'Diastolic': 73, 'Rate': 110}, {'Systolic': 138, 'Diastolic': 99, 'Rate': 72}, {'Systolic': 141, 'Diastolic': 75, 'Rate': 69}, {'Systolic': 149, 'Diastolic': 76, 'Rate': 86}, {'Systolic': 129, 'Diastolic': 73, 'Rate': 110}, {'Systolic': 123, 'Diastolic': 74, 'Rate': 90}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [5], 'patient_info': {'fname': 'Jack', 'lname': 'Smith'}, 'patient_numbers': ['688-563-4368', '485-424-3572', '004-150-1091', '670-082-6299'], 'weights': [302, 246, 272, 370, 232], 'height': 186, 'bp_readings': [{'Systolic': 135, 'Diastolic': 84, 'Rate': 62}, {'Systolic': 111, 'Diastolic': 98, 'Rate': 95}, {'Systolic': 148, 'Diastolic': 70, 'Rate': 94}, {'Systolic': 112, 'Diastolic': 95, 'Rate': 106}, {'Systolic': 144, 'Diastolic': 72, 'Rate': 82}, {'Systolic': 103, 'Diastolic': 88, 'Rate': 62}, {'Systolic': 104, 'Diastolic': 92, 'Rate': 79}, {'Systolic': 113, 'Diastolic': 97, 'Rate': 88}, {'Systolic': 145, 'Diastolic': 76, 'Rate': 108}, {'Systolic': 115, 'Diastolic': 82, 'Rate': 105}]}
# {'_id': 3, 'office_num': [6], 'patient_info': {'fname': 'Liam', 'lname': 'Hart'}, 'patient_numbers': ['553-614-6361', '042-001-4050', '374-018-0384', '189-031-9503'], 'weights': [398, 226], 'height': 135, 'bp_readings': [{'Systolic': 143, 'Diastolic': 75, 'Rate': 79}, {'Systolic': 129, 'Diastolic': 87, 'Rate': 65}]}
# {'_id': 4, 'office_num': [3], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hale'}, 'patient_numbers': ['644-466-9467', '685-335-5079'], 'weights': [246, 133, 212, 376, 130], 'height': 199, 'bp_readings': [{'Systolic': 146, 'Diastolic': 97, 'Rate': 98}, {'Systolic': 123, 'Diastolic': 79, 'Rate': 91}, {'Systolic': 148, 'Diastolic': 72, 'Rate': 79}, {'Systolic': 146, 'Diastolic': 72, 'Rate': 63}, {'Systolic': 130, 'Diastolic': 81, 'Rate': 72}, {'Systolic': 119, 'Diastolic': 82, 'Rate': 67}, {'Systolic': 150, 'Diastolic': 93, 'Rate': 104}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 107}, {'Systolic': 114, 'Diastolic': 81, 'Rate': 90}]}
# {'_id': 5, 'office_num': [10], 'patient_info': {'fname': 'John', 'lname': 'Madden'}, 'patient_numbers': ['826-966-9699', '888-001-2244'], 'weights': [372, 108, 159, 97, 113], 'height': 161, 'bp_readings': [{'Systolic': 130, 'Diastolic': 70, 'Rate': 84}, {'Systolic': 140, 'Diastolic': 73, 'Rate': 80}, {'Systolic': 140, 'Diastolic': 77, 'Rate': 108}, {'Systolic': 114, 'Diastolic': 70, 'Rate': 70}]}
# {'_id': 6, 'office_num': [4], 'patient_info': {'fname': 'Jerry', 'lname': 'Jones'}, 'patient_numbers': ['351-256-9865', '825-618-8377'], 'weights': [383, 169, 133], 'height': 154, 'bp_readings': [{'Systolic': 139, 'Diastolic': 91, 'Rate': 91}, {'Systolic': 114, 'Diastolic': 96, 'Rate': 87}, {'Systolic': 144, 'Diastolic': 76, 'Rate': 81}, {'Systolic': 111, 'Diastolic': 71, 'Rate': 68}]}
# {'_id': 7, 'office_num': [2], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['765-268-8634', '691-243-2953', '917-495-8111', '892-063-0425'], 'weights': [383, 317, 99], 'height': 143, 'bp_readings': [{'Systolic': 135, 'Diastolic': 75, 'Rate': 73}, {'Systolic': 139, 'Diastolic': 80, 'Rate': 109}]}
# {'_id': 8, 'office_num': [4], 'patient_info': {'fname': 'July', 'lname': 'Hart'}, 'patient_numbers': ['515-765-3842', '339-021-7015'], 'weights': [228], 'height': 192, 'bp_readings': [{'Systolic': 139, 'Diastolic': 90, 'Rate': 110}, {'Systolic': 146, 'Diastolic': 99, 'Rate': 60}, {'Systolic': 117, 'Diastolic': 90, 'Rate': 65}, {'Systolic': 145, 'Diastolic': 84, 'Rate': 102}, {'Systolic': 117, 'Diastolic': 96, 'Rate': 84}]}
# {'_id': 9, 'office_num': [9], 'patient_info': {'fname': 'Susan', 'lname': ' Fox'}, 'patient_numbers': ['415-255-0006', '065-511-2193'], 'weights': [262, 210], 'height': 182, 'bp_readings': [{'Systolic': 129, 'Diastolic': 74, 'Rate': 63}, {'Systolic': 111, 'Diastolic': 73, 'Rate': 101}, {'Systolic': 114, 'Diastolic': 94, 'Rate': 79}, {'Systolic': 117, 'Diastolic': 96, 'Rate': 103}, {'Systolic': 138, 'Diastolic': 97, 'Rate': 88}, {'Systolic': 105, 'Diastolic': 92, 'Rate': 87}, {'Systolic': 100, 'Diastolic': 86, 'Rate': 91}, {'Systolic': 147, 'Diastolic': 85, 'Rate': 97}, {'Systolic': 118, 'Diastolic': 82, 'Rate': 73}]}
# {'_id': 10, 'office_num': [10], 'patient_info': {'fname': 'Tom', 'lname': 'Jones'}, 'patient_numbers': ['561-549-8661', '758-553-6268', '834-734-5380'], 'weights': [155, 387, 146, 387], 'height': 176, 'bp_readings': [{'Systolic': 120, 'Diastolic': 83, 'Rate': 62}, {'Systolic': 118, 'Diastolic': 84, 'Rate': 97}, {'Systolic': 149, 'Diastolic': 73, 'Rate': 100}, {'Systolic': 121, 'Diastolic': 73, 'Rate': 63}]}
# {'_id': 11, 'office_num': [2], 'patient_info': {'fname': 'Richard', 'lname': 'Boone'}, 'patient_numbers': ['759-869-5383', '118-235-4372', '558-800-3811'], 'weights': [382], 'height': 189, 'bp_readings': [{'Systolic': 126, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 123, 'Diastolic': 99, 'Rate': 87}, {'Systolic': 141, 'Diastolic': 88, 'Rate': 99}, {'Systolic': 100, 'Diastolic': 82, 'Rate': 86}]}
# {'_id': 12, 'office_num': [8], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Boone'}, 'patient_numbers': ['368-914-9374', '941-921-9008', '351-564-2681', '861-619-4628'], 'weights': [138, 236, 318], 'height': 149, 'bp_readings': [{'Systolic': 128, 'Diastolic': 83, 'Rate': 62}, {'Systolic': 137, 'Diastolic': 96, 'Rate': 96}, {'Systolic': 143, 'Diastolic': 71, 'Rate': 107}, {'Systolic': 135, 'Diastolic': 78, 'Rate': 109}, {'Systolic': 111, 'Diastolic': 94, 'Rate': 81}, {'Systolic': 102, 'Diastolic': 85, 'Rate': 108}]}
# {'_id': 13, 'office_num': [10], 'patient_info': {'fname': 'Susan', 'lname': 'Hart'}, 'patient_numbers': ['464-601-9283', '791-945-0903', '657-395-6120', '776-046-6547'], 'weights': [148, 390, 175], 'height': 103, 'bp_readings': [{'Systolic': 123, 'Diastolic': 96, 'Rate': 70}, {'Systolic': 103, 'Diastolic': 74, 'Rate': 92}, {'Systolic': 112, 'Diastolic': 77, 'Rate': 69}, {'Systolic': 130, 'Diastolic': 74, 'Rate': 99}]}
# {'_id': 14, 'office_num': [2], 'patient_info': {'fname': 'Richard', 'lname': 'Jones'}, 'patient_numbers': ['730-816-5793', '705-047-1075', '870-043-7370', '531-628-3791'], 'weights': [219, 286, 107, 384], 'height': 198, 'bp_readings': [{'Systolic': 138, 'Diastolic': 96, 'Rate': 101}, {'Systolic': 135, 'Diastolic': 90, 'Rate': 73}, {'Systolic': 102, 'Diastolic': 93, 'Rate': 63}, {'Systolic': 123, 'Diastolic': 81, 'Rate': 100}]}
# {'_id': 15, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Hale'}, 'patient_numbers': ['237-563-1700', '941-642-6857'], 'weights': [201], 'height': 147, 'bp_readings': [{'Systolic': 100, 'Diastolic': 93, 'Rate': 88}, {'Systolic': 123, 'Diastolic': 87, 'Rate': 86}, {'Systolic': 150, 'Diastolic': 95, 'Rate': 106}, {'Systolic': 150, 'Diastolic': 75, 'Rate': 86}]}
# {'_id': 16, 'office_num': [5], 'patient_info': {'fname': 'Jordan', 'lname': 'Langston'}, 'patient_numbers': ['741-760-7034', '835-167-4866', '875-878-0466'], 'weights': [96, 195, 368, 318], 'height': 179, 'bp_readings': [{'Systolic': 102, 'Diastolic': 71, 'Rate': 99}, {'Systolic': 134, 'Diastolic': 79, 'Rate': 89}, {'Systolic': 115, 'Diastolic': 80, 'Rate': 82}, {'Systolic': 147, 'Diastolic': 95, 'Rate': 74}, {'Systolic': 119, 'Diastolic': 90, 'Rate': 109}]}
# {'_id': 17, 'office_num': [3], 'patient_info': {'fname': 'Betty', 'lname': 'Granger'}, 'patient_numbers': ['979-366-5437', '861-923-1549', '368-316-1153', '601-214-7678'], 'weights': [339], 'height': 145, 'bp_readings': [{'Systolic': 100, 'Diastolic': 81, 'Rate': 77}, {'Systolic': 103, 'Diastolic': 87, 'Rate': 75}, {'Systolic': 113, 'Diastolic': 72, 'Rate': 84}]}
# {'_id': 18, 'office_num': [6], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['381-213-1276', '252-410-7121'], 'weights': [355, 254, 231, 344], 'height': 185, 'bp_readings': [{'Systolic': 129, 'Diastolic': 86, 'Rate': 64}, {'Systolic': 132, 'Diastolic': 99, 'Rate': 97}, {'Systolic': 118, 'Diastolic': 96, 'Rate': 76}, {'Systolic': 132, 'Diastolic': 86, 'Rate': 70}]}
# {'_id': 19, 'office_num': [3], 'patient_info': {'fname': 'Ethan', 'lname': 'Hale'}, 'patient_numbers': ['745-374-9006', '065-810-9977', '843-356-7132', '358-390-7237'], 'weights': [361, 281, 317], 'height': 103, 'bp_readings': [{'Systolic': 105, 'Diastolic': 97, 'Rate': 100}, {'Systolic': 136, 'Diastolic': 74, 'Rate': 106}, {'Systolic': 102, 'Diastolic': 92, 'Rate': 69}]}
# {'_id': 20, 'office_num': [4], 'patient_info': {'fname': 'James', 'lname': 'Jones'}, 'patient_numbers': ['728-067-0014', '690-904-9399', '107-118-5066'], 'weights': [248, 182, 266], 'height': 158, 'bp_readings': [{'Systolic': 149, 'Diastolic': 79, 'Rate': 109}, {'Systolic': 102, 'Diastolic': 99, 'Rate': 87}, {'Systolic': 109, 'Diastolic': 99, 'Rate': 93}, {'Systolic': 138, 'Diastolic': 83, 'Rate': 90}, {'Systolic': 131, 'Diastolic': 91, 'Rate': 104}, {'Systolic': 114, 'Diastolic': 92, 'Rate': 108}, {'Systolic': 125, 'Diastolic': 70, 'Rate': 75}, {'Systolic': 119, 'Diastolic': 97, 'Rate': 107}]}
# {'_id': 21, 'office_num': [2], 'patient_info': {'fname': 'Jordan', 'lname': 'Hart'}, 'patient_numbers': ['006-060-3087', '970-935-4101', '311-766-4839'], 'weights': [159, 185, 173, 293], 'height': 176, 'bp_readings': [{'Systolic': 115, 'Diastolic': 84, 'Rate': 93}, {'Systolic': 131, 'Diastolic': 98, 'Rate': 89}, {'Systolic': 147, 'Diastolic': 87, 'Rate': 73}, {'Systolic': 104, 'Diastolic': 87, 'Rate': 60}, {'Systolic': 123, 'Diastolic': 93, 'Rate': 89}]}
# {'_id': 22, 'office_num': [1], 'patient_info': {'fname': 'Richard', 'lname': 'Carmichael'}, 'patient_numbers': ['320-622-4745', '993-050-1699', '910-021-3922', '673-455-0511'], 'weights': [322, 115], 'height': 197, 'bp_readings': [{'Systolic': 137, 'Diastolic': 90, 'Rate': 61}, {'Systolic': 107, 'Diastolic': 97, 'Rate': 86}, {'Systolic': 101, 'Diastolic': 90, 'Rate': 69}, {'Systolic': 111, 'Diastolic': 74, 'Rate': 75}, {'Systolic': 122, 'Diastolic': 80, 'Rate': 66}, {'Systolic': 126, 'Diastolic': 70, 'Rate': 64}, {'Systolic': 111, 'Diastolic': 94, 'Rate': 78}]}
# {'_id': 23, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['112-784-2450', '799-702-1038', '608-203-7730', '450-240-1645'], 'weights': [279, 91], 'height': 149, 'bp_readings': [{'Systolic': 128, 'Diastolic': 82, 'Rate': 109}, {'Systolic': 122, 'Diastolic': 94, 'Rate': 68}, {'Systolic': 134, 'Diastolic': 98, 'Rate': 75}, {'Systolic': 112, 'Diastolic': 97, 'Rate': 105}, {'Systolic': 125, 'Diastolic': 96, 'Rate': 67}]}
# {'_id': 24, 'office_num': [5], 'patient_info': {'fname': 'Ethan', 'lname': 'Carmichael'}, 'patient_numbers': ['722-680-6316', '659-058-8792', '721-559-6723'], 'weights': [329], 'height': 154, 'bp_readings': [{'Systolic': 131, 'Diastolic': 70, 'Rate': 85}, {'Systolic': 101, 'Diastolic': 74, 'Rate': 64}]}
# {'_id': 25, 'office_num': [10], 'patient_info': {'fname': 'Richard', 'lname': 'Granger'}, 'patient_numbers': ['211-960-2601', '622-758-4588'], 'weights': [155], 'height': 115, 'bp_readings': [{'Systolic': 143, 'Diastolic': 78, 'Rate': 82}, {'Systolic': 148, 'Diastolic': 73, 'Rate': 67}, {'Systolic': 133, 'Diastolic': 76, 'Rate': 89}, {'Systolic': 143, 'Diastolic': 81, 'Rate': 95}, {'Systolic': 109, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 130, 'Diastolic': 78, 'Rate': 62}, {'Systolic': 101, 'Diastolic': 73, 'Rate': 99}, {'Systolic': 125, 'Diastolic': 88, 'Rate': 67}, {'Systolic': 121, 'Diastolic': 94, 'Rate': 68}, {'Systolic': 146, 'Diastolic': 70, 'Rate': 70}]}
# {'_id': 26, 'office_num': [1], 'patient_info': {'fname': 'Liam', 'lname': 'Jones'}, 'patient_numbers': ['577-067-1521', '003-610-4306'], 'weights': [264, 126, 130, 328], 'height': 169, 'bp_readings': [{'Systolic': 117, 'Diastolic': 86, 'Rate': 92}, {'Systolic': 134, 'Diastolic': 77, 'Rate': 79}, {'Systolic': 113, 'Diastolic': 89, 'Rate': 62}, {'Systolic': 116, 'Diastolic': 92, 'Rate': 88}, {'Systolic': 130, 'Diastolic': 97, 'Rate': 74}, {'Systolic': 113, 'Diastolic': 84, 'Rate': 88}, {'Systolic': 121, 'Diastolic': 74, 'Rate': 108}, {'Systolic': 133, 'Diastolic': 82, 'Rate': 70}, {'Systolic': 130, 'Diastolic': 97, 'Rate': 70}]}
# {'_id': 27, 'office_num': [5], 'patient_info': {'fname': 'James', 'lname': ' Fox'}, 'patient_numbers': ['522-226-3363', '149-897-2640', '445-856-0951'], 'weights': [152, 102, 246, 276, 205], 'height': 176, 'bp_readings': [{'Systolic': 110, 'Diastolic': 92, 'Rate': 96}, {'Systolic': 103, 'Diastolic': 84, 'Rate': 104}, {'Systolic': 134, 'Diastolic': 92, 'Rate': 75}, {'Systolic': 144, 'Diastolic': 96, 'Rate': 61}, {'Systolic': 133, 'Diastolic': 96, 'Rate': 74}, {'Systolic': 137, 'Diastolic': 80, 'Rate': 98}, {'Systolic': 131, 'Diastolic': 82, 'Rate': 76}, {'Systolic': 119, 'Diastolic': 86, 'Rate': 108}, {'Systolic': 144, 'Diastolic': 92, 'Rate': 104}, {'Systolic': 108, 'Diastolic': 97, 'Rate': 78}]}
# {'_id': 28, 'office_num': [7], 'patient_info': {'fname': 'James', 'lname': ' Fox'}, 'patient_numbers': ['128-501-2497', '680-110-7021'], 'weights': [309, 159, 102, 160], 'height': 102, 'bp_readings': [{'Systolic': 121, 'Diastolic': 76, 'Rate': 97}, {'Systolic': 115, 'Diastolic': 82, 'Rate': 100}, {'Systolic': 144, 'Diastolic': 98, 'Rate': 91}, {'Systolic': 140, 'Diastolic': 96, 'Rate': 86}, {'Systolic': 150, 'Diastolic': 86, 'Rate': 60}, {'Systolic': 147, 'Diastolic': 78, 'Rate': 87}, {'Systolic': 128, 'Diastolic': 81, 'Rate': 73}, {'Systolic': 121, 'Diastolic': 93, 'Rate': 97}]}
# {'_id': 29, 'office_num': [4], 'patient_info': {'fname': 'Jordan', 'lname': 'Carmichael'}, 'patient_numbers': ['634-179-5969', '341-548-6944', '633-193-7905', '459-156-9258'], 'weights': [360], 'height': 109, 'bp_readings': [{'Systolic': 150, 'Diastolic': 88, 'Rate': 102}, {'Systolic': 108, 'Diastolic': 91, 'Rate': 63}, {'Systolic': 123, 'Diastolic': 81, 'Rate': 61}, {'Systolic': 116, 'Diastolic': 97, 'Rate': 62}]}
# {'_id': 30, 'office_num': [2], 'patient_info': {'fname': 'Richard', 'lname': 'Madden'}, 'patient_numbers': ['647-667-6973', '155-367-6690'], 'weights': [352, 302], 'height': 106, 'bp_readings': [{'Systolic': 107, 'Diastolic': 73, 'Rate': 71}, {'Systolic': 101, 'Diastolic': 72, 'Rate': 97}, {'Systolic': 106, 'Diastolic': 82, 'Rate': 68}, {'Systolic': 134, 'Diastolic': 85, 'Rate': 61}, {'Systolic': 148, 'Diastolic': 97, 'Rate': 67}, {'Systolic': 144, 'Diastolic': 91, 'Rate': 70}, {'Systolic': 148, 'Diastolic': 86, 'Rate': 106}]}
# {'_id': 31, 'office_num': [2], 'patient_info': {'fname': 'Betty', 'lname': 'Smith'}, 'patient_numbers': ['854-676-4314', '957-569-6245', '161-190-9405'], 'weights': [373, 131, 261, 256], 'height': 129, 'bp_readings': [{'Systolic': 126, 'Diastolic': 86, 'Rate': 110}, {'Systolic': 103, 'Diastolic': 99, 'Rate': 91}, {'Systolic': 138, 'Diastolic': 91, 'Rate': 93}, {'Systolic': 144, 'Diastolic': 90, 'Rate': 101}, {'Systolic': 132, 'Diastolic': 72, 'Rate': 94}, {'Systolic': 106, 'Diastolic': 79, 'Rate': 73}, {'Systolic': 134, 'Diastolic': 98, 'Rate': 76}, {'Systolic': 106, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 125, 'Diastolic': 86, 'Rate': 86}]}
# {'_id': 32, 'office_num': [10], 'patient_info': {'fname': 'Ethan', 'lname': 'Granger'}, 'patient_numbers': ['678-625-8399', '192-946-3245', '058-770-7337'], 'weights': [219, 95, 156, 239, 122], 'height': 195, 'bp_readings': [{'Systolic': 105, 'Diastolic': 75, 'Rate': 84}, {'Systolic': 150, 'Diastolic': 88, 'Rate': 62}, {'Systolic': 139, 'Diastolic': 84, 'Rate': 80}]}
# {'_id': 33, 'office_num': [4], 'patient_info': {'fname': 'Liam', 'lname': 'Hart'}, 'patient_numbers': ['720-982-3960', '608-834-5478', '632-959-1934', '502-805-5639'], 'weights': [142], 'height': 136, 'bp_readings': [{'Systolic': 129, 'Diastolic': 84, 'Rate': 83}, {'Systolic': 133, 'Diastolic': 72, 'Rate': 97}, {'Systolic': 136, 'Diastolic': 92, 'Rate': 82}, {'Systolic': 113, 'Diastolic': 81, 'Rate': 85}]}
# {'_id': 34, 'office_num': [1], 'patient_info': {'fname': 'Jerry', 'lname': 'Smith'}, 'patient_numbers': ['730-994-6321', '226-702-9255'], 'weights': [370, 298, 282, 196, 361], 'height': 119, 'bp_readings': [{'Systolic': 107, 'Diastolic': 94, 'Rate': 91}, {'Systolic': 125, 'Diastolic': 81, 'Rate': 81}]}
# {'_id': 35, 'office_num': [9], 'patient_info': {'fname': 'Jack', 'lname': ' Fox'}, 'patient_numbers': ['079-208-0018', '951-114-9299', '390-364-5668'], 'weights': [390, 337, 376, 350], 'height': 136, 'bp_readings': [{'Systolic': 139, 'Diastolic': 84, 'Rate': 79}, {'Systolic': 133, 'Diastolic': 81, 'Rate': 84}, {'Systolic': 119, 'Diastolic': 76, 'Rate': 94}, {'Systolic': 146, 'Diastolic': 80, 'Rate': 93}]}
# {'_id': 36, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Boone'}, 'patient_numbers': ['141-615-6904', '519-436-2116', '696-105-3807'], 'weights': [255, 325, 95], 'height': 177, 'bp_readings': [{'Systolic': 147, 'Diastolic': 71, 'Rate': 60}, {'Systolic': 144, 'Diastolic': 81, 'Rate': 107}, {'Systolic': 122, 'Diastolic': 85, 'Rate': 98}]}
# {'_id': 37, 'office_num': [1], 'patient_info': {'fname': 'Ethan', 'lname': 'Hale'}, 'patient_numbers': ['689-609-3943', '802-494-8537', '002-405-9372'], 'weights': [373, 320, 137, 382, 227], 'height': 135, 'bp_readings': [{'Systolic': 102, 'Diastolic': 89, 'Rate': 69}, {'Systolic': 137, 'Diastolic': 85, 'Rate': 89}, {'Systolic': 143, 'Diastolic': 93, 'Rate': 73}]}
# {'_id': 38, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Hart'}, 'patient_numbers': ['349-261-5020', '448-174-5392'], 'weights': [311], 'height': 198, 'bp_readings': [{'Systolic': 116, 'Diastolic': 75, 'Rate': 76}, {'Systolic': 117, 'Diastolic': 84, 'Rate': 108}, {'Systolic': 134, 'Diastolic': 86, 'Rate': 109}, {'Systolic': 139, 'Diastolic': 93, 'Rate': 95}, {'Systolic': 112, 'Diastolic': 90, 'Rate': 85}, {'Systolic': 134, 'Diastolic': 83, 'Rate': 67}, {'Systolic': 104, 'Diastolic': 76, 'Rate': 100}, {'Systolic': 145, 'Diastolic': 97, 'Rate': 87}, {'Systolic': 127, 'Diastolic': 84, 'Rate': 105}]}
# {'_id': 39, 'office_num': [3], 'patient_info': {'fname': 'Susan', 'lname': 'Boone'}, 'patient_numbers': ['261-189-5327', '680-739-0252'], 'weights': [144, 203, 304, 218, 146], 'height': 188, 'bp_readings': [{'Systolic': 132, 'Diastolic': 81, 'Rate': 104}, {'Systolic': 132, 'Diastolic': 88, 'Rate': 70}, {'Systolic': 105, 'Diastolic': 98, 'Rate': 90}, {'Systolic': 132, 'Diastolic': 92, 'Rate': 102}, {'Systolic': 143, 'Diastolic': 75, 'Rate': 72}, {'Systolic': 116, 'Diastolic': 84, 'Rate': 70}, {'Systolic': 100, 'Diastolic': 94, 'Rate': 76}, {'Systolic': 111, 'Diastolic': 84, 'Rate': 90}, {'Systolic': 120, 'Diastolic': 97, 'Rate': 80}]}
# {'_id': 40, 'office_num': [5], 'patient_info': {'fname': 'John', 'lname': ' Fox'}, 'patient_numbers': ['275-413-2101', '038-368-5711', '250-413-6396', '484-212-0457'], 'weights': [235, 376, 121], 'height': 200, 'bp_readings': [{'Systolic': 146, 'Diastolic': 88, 'Rate': 73}, {'Systolic': 101, 'Diastolic': 91, 'Rate': 76}, {'Systolic': 107, 'Diastolic': 82, 'Rate': 81}, {'Systolic': 139, 'Diastolic': 91, 'Rate': 85}, {'Systolic': 123, 'Diastolic': 89, 'Rate': 103}, {'Systolic': 132, 'Diastolic': 91, 'Rate': 84}]}
# {'_id': 41, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': 'Boone'}, 'patient_numbers': ['772-697-9735', '031-724-4824'], 'weights': [240, 124], 'height': 151, 'bp_readings': [{'Systolic': 147, 'Diastolic': 93, 'Rate': 79}, {'Systolic': 126, 'Diastolic': 78, 'Rate': 66}, {'Systolic': 121, 'Diastolic': 77, 'Rate': 103}]}
# {'_id': 42, 'office_num': [1], 'patient_info': {'fname': 'Jordan', 'lname': 'Hale'}, 'patient_numbers': ['689-191-9208', '380-759-4390'], 'weights': [327, 324], 'height': 139, 'bp_readings': [{'Systolic': 111, 'Diastolic': 93, 'Rate': 88}, {'Systolic': 128, 'Diastolic': 70, 'Rate': 85}, {'Systolic': 106, 'Diastolic': 74, 'Rate': 67}, {'Systolic': 150, 'Diastolic': 86, 'Rate': 65}, {'Systolic': 143, 'Diastolic': 92, 'Rate': 110}, {'Systolic': 100, 'Diastolic': 88, 'Rate': 84}, {'Systolic': 108, 'Diastolic': 88, 'Rate': 65}]}
# {'_id': 43, 'office_num': [3], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['108-339-5426', '526-158-1064', '355-153-6767'], 'weights': [291, 196], 'height': 190, 'bp_readings': [{'Systolic': 127, 'Diastolic': 85, 'Rate': 102}, {'Systolic': 126, 'Diastolic': 76, 'Rate': 71}, {'Systolic': 141, 'Diastolic': 97, 'Rate': 91}, {'Systolic': 119, 'Diastolic': 78, 'Rate': 89}]}
# {'_id': 44, 'office_num': [2], 'patient_info': {'fname': 'July', 'lname': 'Hale'}, 'patient_numbers': ['125-192-9675', '646-640-0145', '042-508-4678', '959-615-8615'], 'weights': [301, 393, 271, 260], 'height': 136, 'bp_readings': [{'Systolic': 101, 'Diastolic': 87, 'Rate': 75}, {'Systolic': 115, 'Diastolic': 73, 'Rate': 92}, {'Systolic': 140, 'Diastolic': 94, 'Rate': 66}, {'Systolic': 136, 'Diastolic': 80, 'Rate': 71}]}
# {'_id': 45, 'office_num': [2], 'patient_info': {'fname': 'Betty', 'lname': ' Fox'}, 'patient_numbers': ['856-669-9488', '375-430-0588'], 'weights': [250, 198], 'height': 147, 'bp_readings': [{'Systolic': 136, 'Diastolic': 83, 'Rate': 83}, {'Systolic': 117, 'Diastolic': 72, 'Rate': 90}, {'Systolic': 124, 'Diastolic': 98, 'Rate': 92}, {'Systolic': 100, 'Diastolic': 76, 'Rate': 89}, {'Systolic': 120, 'Diastolic': 94, 'Rate': 92}]}
# {'_id': 46, 'office_num': [6], 'patient_info': {'fname': 'Ethan', 'lname': 'Carmichael'}, 'patient_numbers': ['253-616-7081', '948-443-0949', '121-076-3677'], 'weights': [365], 'height': 174, 'bp_readings': [{'Systolic': 130, 'Diastolic': 99, 'Rate': 106}, {'Systolic': 131, 'Diastolic': 81, 'Rate': 72}, {'Systolic': 114, 'Diastolic': 70, 'Rate': 73}, {'Systolic': 143, 'Diastolic': 78, 'Rate': 84}, {'Systolic': 120, 'Diastolic': 94, 'Rate': 110}, {'Systolic': 127, 'Diastolic': 74, 'Rate': 89}, {'Systolic': 140, 'Diastolic': 93, 'Rate': 94}]}
# {'_id': 47, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hart'}, 'patient_numbers': ['177-182-7375', '403-883-9757', '357-114-9144'], 'weights': [122], 'height': 141, 'bp_readings': [{'Systolic': 132, 'Diastolic': 70, 'Rate': 99}, {'Systolic': 106, 'Diastolic': 95, 'Rate': 84}, {'Systolic': 130, 'Diastolic': 72, 'Rate': 79}, {'Systolic': 105, 'Diastolic': 76, 'Rate': 79}]}
# {'_id': 48, 'office_num': [7], 'patient_info': {'fname': 'Ethan', 'lname': 'Jones'}, 'patient_numbers': ['286-624-5269', '399-862-9632', '602-235-3521'], 'weights': [237], 'height': 131, 'bp_readings': [{'Systolic': 108, 'Diastolic': 86, 'Rate': 81}, {'Systolic': 101, 'Diastolic': 97, 'Rate': 66}, {'Systolic': 101, 'Diastolic': 95, 'Rate': 79}, {'Systolic': 124, 'Diastolic': 99, 'Rate': 60}, {'Systolic': 150, 'Diastolic': 76, 'Rate': 91}, {'Systolic': 138, 'Diastolic': 94, 'Rate': 97}, {'Systolic': 110, 'Diastolic': 88, 'Rate': 65}, {'Systolic': 133, 'Diastolic': 93, 'Rate': 86}, {'Systolic': 146, 'Diastolic': 96, 'Rate': 83}]}
# {'_id': 49, 'office_num': [6], 'patient_info': {'fname': 'John', 'lname': 'Granger'}, 'patient_numbers': ['518-346-9142', '954-087-9938'], 'weights': [272, 140], 'height': 122, 'bp_readings': [{'Systolic': 112, 'Diastolic': 83, 'Rate': 109}, {'Systolic': 137, 'Diastolic': 97, 'Rate': 87}, {'Systolic': 146, 'Diastolic': 94, 'Rate': 100}, {'Systolic': 150, 'Diastolic': 80, 'Rate': 100}, {'Systolic': 146, 'Diastolic': 99, 'Rate': 69}, {'Systolic': 144, 'Diastolic': 90, 'Rate': 93}, {'Systolic': 132, 'Diastolic': 78, 'Rate': 91}, {'Systolic': 141, 'Diastolic': 84, 'Rate': 72}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for all values for id 1
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Granger",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "069-023-3236",
#         "608-843-1903",
#         "823-191-2834"
#     ],
#     "weights": [
#         245,
#         161,
#         393,
#         353,
#         276
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 85
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 76,
#             "Rate": 92
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 99,
#             "Rate": 72
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 75,
#             "Rate": 69
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 76,
#             "Rate": 86
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 74,
#             "Rate": 90
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Granger",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "069-023-3236",
#         "608-843-1903",
#         "823-191-2834"
#     ],
#     "weights": [
#         245,
#         161,
#         393,
#         353,
#         276
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 85
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 76,
#             "Rate": 92
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 99,
#             "Rate": 72
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 75,
#             "Rate": 69
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 76,
#             "Rate": 86
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 74,
#             "Rate": 90
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Granger",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "842-565-1484",
#         "078-427-3068",
#         "774-332-7162",
#         "480-478-2742"
#     ],
#     "weights": [
#         194,
#         202,
#         139,
#         269,
#         136
#     ],
#     "height": 178,
#     "bp_readings": [
#         {
#             "Systolic": 142,
#             "Diastolic": 79,
#             "Rate": 78
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 74,
#             "Rate": 104
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 73,
#             "Rate": 97
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 91,
#             "Rate": 75
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 79,
#             "Rate": 85
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 87,
#             "Rate": 94
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 79,
#             "Rate": 95
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 74,
#             "Rate": 106
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 72,
#             "Rate": 84
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^707'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %%
query = { "bp_readings": {"Systolic" : 104 , "Diastolic": 82, "Rate": 81}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 104}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 142} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Granger",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "069-023-3236",
#         "608-843-1903",
#         "823-191-2834"
#     ],
#     "weights": [
#         245,
#         161,
#         393,
#         353,
#         276
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 85
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 76,
#             "Rate": 92
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 99,
#             "Rate": 72
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 75,
#             "Rate": 69
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 76,
#             "Rate": 86
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 73,
#             "Rate": 110
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 74,
#             "Rate": 90
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 2,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "688-563-4368",
#         "485-424-3572",
#         "004-150-1091",
#         "670-082-6299"
#     ],
#     "weights": [
#         302,
#         246,
#         272,
#         370,
#         232
#     ],
#     "height": 186,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 84,
#             "Rate": 62
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 98,
#             "Rate": 95
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 70,
#             "Rate": 94
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 95,
#             "Rate": 106
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 72,
#             "Rate": 82
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 88,
#             "Rate": 62
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 79
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 97,
#             "Rate": 88
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 108
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 3,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "553-614-6361",
#         "042-001-4050",
#         "374-018-0384",
#         "189-031-9503"
#     ],
#     "weights": [
#         398,
#         226
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 79
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 87,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 4,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "644-466-9467",
#         "685-335-5079"
#     ],
#     "weights": [
#         246,
#         133,
#         212,
#         376,
#         130
#     ],
#     "height": 199,
#     "bp_readings": [
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 98
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 79,
#             "Rate": 91
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 72,
#             "Rate": 79
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 72,
#             "Rate": 63
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 81,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 82,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 93,
#             "Rate": 104
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 107
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 81,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 5,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "826-966-9699",
#         "888-001-2244"
#     ],
#     "weights": [
#         372,
#         108,
#         159,
#         97,
#         113
#     ],
#     "height": 161,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 70,
#             "Rate": 84
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 73,
#             "Rate": 80
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 77,
#             "Rate": 108
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 70,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "351-256-9865",
#         "825-618-8377"
#     ],
#     "weights": [
#         383,
#         169,
#         133
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 91,
#             "Rate": 91
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 96,
#             "Rate": 87
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 76,
#             "Rate": 81
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 71,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "765-268-8634",
#         "691-243-2953",
#         "917-495-8111",
#         "892-063-0425"
#     ],
#     "weights": [
#         383,
#         317,
#         99
#     ],
#     "height": 143,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 75,
#             "Rate": 73
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 80,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "515-765-3842",
#         "339-021-7015"
#     ],
#     "weights": [
#         228
#     ],
#     "height": 192,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 90,
#             "Rate": 110
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 99,
#             "Rate": 60
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 90,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 84,
#             "Rate": 102
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 96,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "415-255-0006",
#         "065-511-2193"
#     ],
#     "weights": [
#         262,
#         210
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 74,
#             "Rate": 63
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 73,
#             "Rate": 101
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 94,
#             "Rate": 79
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 96,
#             "Rate": 103
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 97,
#             "Rate": 88
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 92,
#             "Rate": 87
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 86,
#             "Rate": 91
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 85,
#             "Rate": 97
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 82,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 10,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "561-549-8661",
#         "758-553-6268",
#         "834-734-5380"
#     ],
#     "weights": [
#         155,
#         387,
#         146,
#         387
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 83,
#             "Rate": 62
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 84,
#             "Rate": 97
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 73,
#             "Rate": 100
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 73,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 11,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "759-869-5383",
#         "118-235-4372",
#         "558-800-3811"
#     ],
#     "weights": [
#         382
#     ],
#     "height": 189,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 93,
#             "Rate": 102
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 99,
#             "Rate": 87
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 88,
#             "Rate": 99
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 82,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "368-914-9374",
#         "941-921-9008",
#         "351-564-2681",
#         "861-619-4628"
#     ],
#     "weights": [
#         138,
#         236,
#         318
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 83,
#             "Rate": 62
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 96,
#             "Rate": 96
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 71,
#             "Rate": 107
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 78,
#             "Rate": 109
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 94,
#             "Rate": 81
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 85,
#             "Rate": 108
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "464-601-9283",
#         "791-945-0903",
#         "657-395-6120",
#         "776-046-6547"
#     ],
#     "weights": [
#         148,
#         390,
#         175
#     ],
#     "height": 103,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 96,
#             "Rate": 70
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 74,
#             "Rate": 92
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 74,
#             "Rate": 99
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "730-816-5793",
#         "705-047-1075",
#         "870-043-7370",
#         "531-628-3791"
#     ],
#     "weights": [
#         219,
#         286,
#         107,
#         384
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 138,
#             "Diastolic": 96,
#             "Rate": 101
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 90,
#             "Rate": 73
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 93,
#             "Rate": 63
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 81,
#             "Rate": 100
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "237-563-1700",
#         "941-642-6857"
#     ],
#     "weights": [
#         201
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 93,
#             "Rate": 88
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 87,
#             "Rate": 86
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 95,
#             "Rate": 106
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 75,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "741-760-7034",
#         "835-167-4866",
#         "875-878-0466"
#     ],
#     "weights": [
#         96,
#         195,
#         368,
#         318
#     ],
#     "height": 179,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 71,
#             "Rate": 99
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 79,
#             "Rate": 89
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 80,
#             "Rate": 82
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 95,
#             "Rate": 74
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 90,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "381-213-1276",
#         "252-410-7121"
#     ],
#     "weights": [
#         355,
#         254,
#         231,
#         344
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 86,
#             "Rate": 64
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 99,
#             "Rate": 97
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 96,
#             "Rate": 76
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 86,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 19,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "745-374-9006",
#         "065-810-9977",
#         "843-356-7132",
#         "358-390-7237"
#     ],
#     "weights": [
#         361,
#         281,
#         317
#     ],
#     "height": 103,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 97,
#             "Rate": 100
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 74,
#             "Rate": 106
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 92,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 20,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "728-067-0014",
#         "690-904-9399",
#         "107-118-5066"
#     ],
#     "weights": [
#         248,
#         182,
#         266
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 79,
#             "Rate": 109
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 99,
#             "Rate": 87
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 99,
#             "Rate": 93
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 83,
#             "Rate": 90
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 91,
#             "Rate": 104
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 92,
#             "Rate": 108
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 70,
#             "Rate": 75
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 97,
#             "Rate": 107
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "006-060-3087",
#         "970-935-4101",
#         "311-766-4839"
#     ],
#     "weights": [
#         159,
#         185,
#         173,
#         293
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 115,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 98,
#             "Rate": 89
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 87,
#             "Rate": 73
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 87,
#             "Rate": 60
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 93,
#             "Rate": 89
#         }
#     ]
# }
# {
#     "_id": 22,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "320-622-4745",
#         "993-050-1699",
#         "910-021-3922",
#         "673-455-0511"
#     ],
#     "weights": [
#         322,
#         115
#     ],
#     "height": 197,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 90,
#             "Rate": 61
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 97,
#             "Rate": 86
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 90,
#             "Rate": 69
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 74,
#             "Rate": 75
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 80,
#             "Rate": 66
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 70,
#             "Rate": 64
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 94,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 23,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "112-784-2450",
#         "799-702-1038",
#         "608-203-7730",
#         "450-240-1645"
#     ],
#     "weights": [
#         279,
#         91
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 82,
#             "Rate": 109
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 94,
#             "Rate": 68
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 98,
#             "Rate": 75
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 97,
#             "Rate": 105
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 96,
#             "Rate": 67
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "722-680-6316",
#         "659-058-8792",
#         "721-559-6723"
#     ],
#     "weights": [
#         329
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 70,
#             "Rate": 85
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 74,
#             "Rate": 64
#         }
#     ]
# }
# {
#     "_id": 25,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "211-960-2601",
#         "622-758-4588"
#     ],
#     "weights": [
#         155
#     ],
#     "height": 115,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 78,
#             "Rate": 82
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 73,
#             "Rate": 67
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 76,
#             "Rate": 89
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 81,
#             "Rate": 95
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 78,
#             "Rate": 62
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 73,
#             "Rate": 99
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 88,
#             "Rate": 67
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 94,
#             "Rate": 68
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 70,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "577-067-1521",
#         "003-610-4306"
#     ],
#     "weights": [
#         264,
#         126,
#         130,
#         328
#     ],
#     "height": 169,
#     "bp_readings": [
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 92
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 77,
#             "Rate": 79
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 89,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 92,
#             "Rate": 88
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 97,
#             "Rate": 74
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 84,
#             "Rate": 88
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 74,
#             "Rate": 108
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 82,
#             "Rate": 70
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 97,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "522-226-3363",
#         "149-897-2640",
#         "445-856-0951"
#     ],
#     "weights": [
#         152,
#         102,
#         246,
#         276,
#         205
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 92,
#             "Rate": 96
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 84,
#             "Rate": 104
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 92,
#             "Rate": 75
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 96,
#             "Rate": 61
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 96,
#             "Rate": 74
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 80,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 82,
#             "Rate": 76
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 86,
#             "Rate": 108
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 92,
#             "Rate": 104
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 97,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "128-501-2497",
#         "680-110-7021"
#     ],
#     "weights": [
#         309,
#         159,
#         102,
#         160
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 121,
#             "Diastolic": 76,
#             "Rate": 97
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 98,
#             "Rate": 91
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 96,
#             "Rate": 86
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 86,
#             "Rate": 60
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 78,
#             "Rate": 87
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 81,
#             "Rate": 73
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 93,
#             "Rate": 97
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "634-179-5969",
#         "341-548-6944",
#         "633-193-7905",
#         "459-156-9258"
#     ],
#     "weights": [
#         360
#     ],
#     "height": 109,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 102
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 91,
#             "Rate": 63
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 81,
#             "Rate": 61
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 97,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "647-667-6973",
#         "155-367-6690"
#     ],
#     "weights": [
#         352,
#         302
#     ],
#     "height": 106,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 72,
#             "Rate": 97
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 82,
#             "Rate": 68
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 85,
#             "Rate": 61
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 97,
#             "Rate": 67
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 91,
#             "Rate": 70
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 86,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "854-676-4314",
#         "957-569-6245",
#         "161-190-9405"
#     ],
#     "weights": [
#         373,
#         131,
#         261,
#         256
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 86,
#             "Rate": 110
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 99,
#             "Rate": 91
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 91,
#             "Rate": 93
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 101
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 72,
#             "Rate": 94
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 79,
#             "Rate": 73
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 98,
#             "Rate": 76
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 93,
#             "Rate": 102
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 86,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "678-625-8399",
#         "192-946-3245",
#         "058-770-7337"
#     ],
#     "weights": [
#         219,
#         95,
#         156,
#         239,
#         122
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 75,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 62
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 84,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 33,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "720-982-3960",
#         "608-834-5478",
#         "632-959-1934",
#         "502-805-5639"
#     ],
#     "weights": [
#         142
#     ],
#     "height": 136,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 84,
#             "Rate": 83
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 72,
#             "Rate": 97
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 92,
#             "Rate": 82
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 81,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "079-208-0018",
#         "951-114-9299",
#         "390-364-5668"
#     ],
#     "weights": [
#         390,
#         337,
#         376,
#         350
#     ],
#     "height": 136,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 81,
#             "Rate": 84
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 76,
#             "Rate": 94
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 80,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "141-615-6904",
#         "519-436-2116",
#         "696-105-3807"
#     ],
#     "weights": [
#         255,
#         325,
#         95
#     ],
#     "height": 177,
#     "bp_readings": [
#         {
#             "Systolic": 147,
#             "Diastolic": 71,
#             "Rate": 60
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 81,
#             "Rate": 107
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 85,
#             "Rate": 98
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "689-609-3943",
#         "802-494-8537",
#         "002-405-9372"
#     ],
#     "weights": [
#         373,
#         320,
#         137,
#         382,
#         227
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 89,
#             "Rate": 69
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 85,
#             "Rate": 89
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 93,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "349-261-5020",
#         "448-174-5392"
#     ],
#     "weights": [
#         311
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 75,
#             "Rate": 76
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 84,
#             "Rate": 108
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 86,
#             "Rate": 109
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 93,
#             "Rate": 95
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 90,
#             "Rate": 85
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 83,
#             "Rate": 67
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 76,
#             "Rate": 100
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 97,
#             "Rate": 87
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "261-189-5327",
#         "680-739-0252"
#     ],
#     "weights": [
#         144,
#         203,
#         304,
#         218,
#         146
#     ],
#     "height": 188,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 81,
#             "Rate": 104
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 88,
#             "Rate": 70
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 98,
#             "Rate": 90
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 92,
#             "Rate": 102
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 72
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 84,
#             "Rate": 70
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 94,
#             "Rate": 76
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 84,
#             "Rate": 90
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 97,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "275-413-2101",
#         "038-368-5711",
#         "250-413-6396",
#         "484-212-0457"
#     ],
#     "weights": [
#         235,
#         376,
#         121
#     ],
#     "height": 200,
#     "bp_readings": [
#         {
#             "Systolic": 146,
#             "Diastolic": 88,
#             "Rate": 73
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 91,
#             "Rate": 76
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 82,
#             "Rate": 81
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 91,
#             "Rate": 85
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 89,
#             "Rate": 103
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 91,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "772-697-9735",
#         "031-724-4824"
#     ],
#     "weights": [
#         240,
#         124
#     ],
#     "height": 151,
#     "bp_readings": [
#         {
#             "Systolic": 147,
#             "Diastolic": 93,
#             "Rate": 79
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 78,
#             "Rate": 66
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 77,
#             "Rate": 103
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "689-191-9208",
#         "380-759-4390"
#     ],
#     "weights": [
#         327,
#         324
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 93,
#             "Rate": 88
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 70,
#             "Rate": 85
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 74,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 86,
#             "Rate": 65
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 92,
#             "Rate": 110
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 88,
#             "Rate": 84
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 88,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 43,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "108-339-5426",
#         "526-158-1064",
#         "355-153-6767"
#     ],
#     "weights": [
#         291,
#         196
#     ],
#     "height": 190,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 85,
#             "Rate": 102
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 76,
#             "Rate": 71
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 97,
#             "Rate": 91
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 78,
#             "Rate": 89
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "125-192-9675",
#         "646-640-0145",
#         "042-508-4678",
#         "959-615-8615"
#     ],
#     "weights": [
#         301,
#         393,
#         271,
#         260
#     ],
#     "height": 136,
#     "bp_readings": [
#         {
#             "Systolic": 101,
#             "Diastolic": 87,
#             "Rate": 75
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 73,
#             "Rate": 92
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 94,
#             "Rate": 66
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 80,
#             "Rate": 71
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "856-669-9488",
#         "375-430-0588"
#     ],
#     "weights": [
#         250,
#         198
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 136,
#             "Diastolic": 83,
#             "Rate": 83
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 72,
#             "Rate": 90
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 98,
#             "Rate": 92
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 76,
#             "Rate": 89
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 94,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 46,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "253-616-7081",
#         "948-443-0949",
#         "121-076-3677"
#     ],
#     "weights": [
#         365
#     ],
#     "height": 174,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 99,
#             "Rate": 106
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 81,
#             "Rate": 72
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 70,
#             "Rate": 73
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 78,
#             "Rate": 84
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 94,
#             "Rate": 110
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 74,
#             "Rate": 89
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 94
#         }
#     ]
# }
# {
#     "_id": 47,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "177-182-7375",
#         "403-883-9757",
#         "357-114-9144"
#     ],
#     "weights": [
#         122
#     ],
#     "height": 141,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 70,
#             "Rate": 99
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 95,
#             "Rate": 84
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 72,
#             "Rate": 79
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 76,
#             "Rate": 79
#         }
#     ]
# }
# {
#     "_id": 48,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "286-624-5269",
#         "399-862-9632",
#         "602-235-3521"
#     ],
#     "weights": [
#         237
#     ],
#     "height": 131,
#     "bp_readings": [
#         {
#             "Systolic": 108,
#             "Diastolic": 86,
#             "Rate": 81
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 97,
#             "Rate": 66
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 95,
#             "Rate": 79
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 99,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 76,
#             "Rate": 91
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 97
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 88,
#             "Rate": 65
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 93,
#             "Rate": 86
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 96,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "518-346-9142",
#         "954-087-9938"
#     ],
#     "weights": [
#         272,
#         140
#     ],
#     "height": 122,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 109
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 97,
#             "Rate": 87
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 94,
#             "Rate": 100
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 100
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 99,
#             "Rate": 69
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 93
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 78,
#             "Rate": 91
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 84,
#             "Rate": 72
#         }
#     ]
# }

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 2,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "688-563-4368",
#         "485-424-3572",
#         "004-150-1091",
#         "670-082-6299"
#     ],
#     "weights": [
#         302,
#         246,
#         272,
#         370,
#         232
#     ],
#     "height": 186,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 84,
#             "Rate": 62
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 98,
#             "Rate": 95
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 70,
#             "Rate": 94
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 95,
#             "Rate": 106
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 72,
#             "Rate": 82
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 88,
#             "Rate": 62
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 79
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 97,
#             "Rate": 88
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 108
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "006-060-3087",
#         "970-935-4101",
#         "311-766-4839"
#     ],
#     "weights": [
#         159,
#         185,
#         173,
#         293
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 115,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 98,
#             "Rate": 89
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 87,
#             "Rate": 73
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 87,
#             "Rate": 60
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 93,
#             "Rate": 89
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "349-261-5020",
#         "448-174-5392"
#     ],
#     "weights": [
#         311
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 75,
#             "Rate": 76
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 84,
#             "Rate": 108
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 86,
#             "Rate": 109
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 93,
#             "Rate": 95
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 90,
#             "Rate": 85
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 83,
#             "Rate": 67
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 76,
#             "Rate": 100
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 97,
#             "Rate": 87
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 105
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 4,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "644-466-9467",
#         "685-335-5079"
#     ],
#     "weights": [
#         246,
#         133,
#         212,
#         376,
#         130
#     ],
#     "height": 199,
#     "bp_readings": [
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 98
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 79,
#             "Rate": 91
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 72,
#             "Rate": 79
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 72,
#             "Rate": 63
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 81,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 82,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 93,
#             "Rate": 104
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 107
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 81,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "237-563-1700",
#         "941-642-6857"
#     ],
#     "weights": [
#         201
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 93,
#             "Rate": 88
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 87,
#             "Rate": 86
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 95,
#             "Rate": 106
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 75,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "128-501-2497",
#         "680-110-7021"
#     ],
#     "weights": [
#         309,
#         159,
#         102,
#         160
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 121,
#             "Diastolic": 76,
#             "Rate": 97
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 98,
#             "Rate": 91
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 96,
#             "Rate": 86
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 86,
#             "Rate": 60
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 78,
#             "Rate": 87
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 81,
#             "Rate": 73
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 93,
#             "Rate": 97
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "634-179-5969",
#         "341-548-6944",
#         "633-193-7905",
#         "459-156-9258"
#     ],
#     "weights": [
#         360
#     ],
#     "height": 109,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 102
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 91,
#             "Rate": 63
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 81,
#             "Rate": 61
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 97,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "678-625-8399",
#         "192-946-3245",
#         "058-770-7337"
#     ],
#     "weights": [
#         219,
#         95,
#         156,
#         239,
#         122
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 75,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 62
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 84,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "689-191-9208",
#         "380-759-4390"
#     ],
#     "weights": [
#         327,
#         324
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 93,
#             "Rate": 88
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 70,
#             "Rate": 85
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 74,
#             "Rate": 67
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 86,
#             "Rate": 65
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 92,
#             "Rate": 110
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 88,
#             "Rate": 84
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 88,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 48,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "286-624-5269",
#         "399-862-9632",
#         "602-235-3521"
#     ],
#     "weights": [
#         237
#     ],
#     "height": 131,
#     "bp_readings": [
#         {
#             "Systolic": 108,
#             "Diastolic": 86,
#             "Rate": 81
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 97,
#             "Rate": 66
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 95,
#             "Rate": 79
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 99,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 76,
#             "Rate": 91
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 97
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 88,
#             "Rate": 65
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 93,
#             "Rate": 86
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 96,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "518-346-9142",
#         "954-087-9938"
#     ],
#     "weights": [
#         272,
#         140
#     ],
#     "height": 122,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 109
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 97,
#             "Rate": 87
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 94,
#             "Rate": 100
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 100
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 99,
#             "Rate": 69
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 93
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 78,
#             "Rate": 91
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 84,
#             "Rate": 72
#         }
#     ]
# }

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
